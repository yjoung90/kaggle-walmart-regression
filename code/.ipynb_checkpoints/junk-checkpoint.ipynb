# %%
## testing

# %%
key = pd.read_csv('data/key.csv')
train = pd.read_csv('data/train.csv')
weather = pd.read_csv('data/weather.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-994d3ef6c999> in <module>()
# ----> 1 key = pd.read_csv('data/key.csv')
#       2 train = pd.read_csv('data/train.csv')
#       3 weather = pd.read_csv('data/weather.csv')
#
# ...

# %%
weather_new = weather[:8968]

# %%
weather_new # 2013년 3월 31일까지의 weather data

# %%
weather_new.loc[:, ['tmax', 'tmin', 'tavg', 'depart', 'heat', 'cool']]
# Out:
#      tmax tmin tavg depart heat cool
# 0      52   31   42      M   23    0
# 1      48   33   41     16   24    0
# 2      55   34   45      9   20    0
# 3      63   47   55      4   10    0
# 4      63   34   49      0   16    0
# 5      50   33   42      M   23    0
# 6      66   45    M      M    M    M
# 7      34   19   27      M   38    0
# 8      73   53   63      M    2    0
# 9      72   48   60      7    5    0
# 10     72   48   60      M    5    0
# 11     38   18   28      M   37    0
# 12     50   34   42      5   23    0
# 13     48   26   37     16   28    0
# 14     50   30   40      M   25    0
# 15     56   38   47      M   18    0
# 16     59   40   50      4   15    0
# 17     38   25   32     10   33    0
# 18     59   41   50      M   15    0
# 19     50   31   41      M   24    0
# 20     46   28   37     12   28    0
# 21     45   24   35     -1   30    0
# 22     60   37   49     -2   16    0
# 23     60   30   45     -4   20    0
# ...

# %%
weather_new.loc[:, ['depart', 'tavg', 'heat', 'cool']]
# Out:
#      depart tavg heat cool
# 0         M   42   23    0
# 1        16   41   24    0
# 2         9   45   20    0
# 3         4   55   10    0
# 4         0   49   16    0
# 5         M   42   23    0
# 6         M    M    M    M
# 7         M   27   38    0
# 8         M   63    2    0
# 9         7   60    5    0
# 10        M   60    5    0
# 11        M   28   37    0
# 12        5   42   23    0
# 13       16   37   28    0
# 14        M   40   25    0
# 15        M   47   18    0
# 16        4   50   15    0
# 17       10   32   33    0
# 18        M   50   15    0
# 19        M   41   24    0
# 20       12   37   28    0
# 21       -1   35   30    0
# 22       -2   49   16    0
# 23       -4   45   20    0
# 24        M   35   30    0
# 25        M    M    M    M
# 26        M   16   49    0
# 27        M   55   10    0
# 28       -1   52   13    0
# 29        M   56    9    0
# ...     ...  ...  ...  ...
# 8938     -5   59    6    0
# 8939      M   61    4    0
# ...
